# %% [markdown]
# <a href="https://colab.research.google.com/github/kashiki225121/ActivityLifeCycle/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.flush_and_unmount()

# %%
with open('/content/drive/MyDrive/Test/test.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/MyDrive/Test/test.txt
# Out:
# Hello Google Drive!

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/Test/DataMahasiswa.csv')
data

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-0622742f-23f6-4e66-9fa9-183cdc9c9d0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0622742f-23f6-4e66-9fa9-183cdc9c9d0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data_Mahasiswa.csv to Data_Mahasiswa.csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(file['Data_Mahasiswa.csv']))
df2
# Out:
#    Unnamed: 0  ...                Unnamed: 7
# 0          No  ...               Data Vaksin
# 1           1  ...  Vaksin ke-1, Vaksin ke-2
# 2           2  ...               Vaksin ke-1
# 3           3  ...  Vaksin ke-1, Vaksin ke-2
# 4           4  ...  vaksin ke - 1 dan ke - 2
# 5           5  ...  Vaksin ke-1, Vaksin ke-2
# 6           6  ...             Vaksin ke - 1
# 7           7  ...               Vaksin ke-1
# 8           8  ...  Vaksin ke-1, Vaksin ke-2
# 9           9  ...  Vaksin ke-1, Vaksin ke-2
# 10         10  ...  Vaksin ke-1, Vaksin ke-2
# 11         11  ...  Vaksin ke-1, Vaksin ke-2
# 12         12  ...               Vaksin ke-1
# 13         13  ...               Vaksin ke-1
# 14         14  ...  Vaksin ke-1, Vaksin ke-2
# 15         15  ...  Vaksin ke-1, Vaksin ke-2
# 16         16  ...  Vaksin ke-1, Vaksin ke-2
# 17         17  ...       vaksin 1 , vaksin 2
# 18         18  ...               Vaksin ke-1
# 19         19  ...  Vaksin ke-1, Vaksin ke-2
# 20         20  ...   Vaksin ke-1,Vaksin ke-2
# 21         21  ...  Vaksin ke-1, Vaksin ke-2
# 22         22  ...                     Belum
# 23         23  ...  Vaksin ke-1, Vaksin ke-2
# 24         24  ...  vaksin ke-1, vaksin ke-2
# 25         25  ...  vaksin ke-1, vaksin ke-2
# 26         26  ...  vaksin ke-1, vaksin ke-2
# 27         27  ...  Vaksin ke-1, Vaksin ke-2
# 28         28  ...  Vaksin ke-1, Vaksin ke-2
# 29         29  ...                     Belum
# 30         30  ...  Vaksin ke-1, Vaksin ke-2
# 31         31  ...  Vaksin ke-1, Vaksin ke-2
#
# [32 rows x 8 columns]
